# %% [markdown]
# ## Working with Missing Data in Pandas

# %%
import numpy as np
import pandas as pd

from pandas import DataFrame

# %% [markdown]
# ### Filling missing values using fillna(), replace() and interpolate()

# %%
data= {'name':['steve', 'john', 'tim', 'tom', 'jolin', 'mathew', 'micheal'],
       'age':[20,22,21,20,24,21,23],
        'gender':['male','male','male','male','female','male','male'],
         'rank':[2,1,4,5,6,7,6] }
ranking_df = DataFrame(data)
ranking_df.iloc[2:5,1]= np.nan
ranking_df.iloc[3:6,3]= np.nan
ranking_df.iloc[3,:]= np.nan
ranking_df
# Out:
#       name   age  gender  rank
# 0    steve  20.0    male   2.0
# 1     john  22.0    male   1.0
# 2      tim   NaN    male   4.0
# 3      NaN   NaN     NaN   NaN
# 4    jolin   NaN  female   NaN
# 5   mathew  21.0    male   NaN
# 6  micheal  23.0    male   6.0

# %%
ranking_df.isnull() #true if value is NaN
# Out:
#     name    age  gender   rank
# 0  False  False   False  False
# 1  False  False   False  False
# 2  False   True   False  False
# 3   True   True    True   True
# 4  False   True   False   True
# 5  False  False   False   True
# 6  False  False   False  False

# %%
ranking_df.notnull()
# Out:
#     name    age  gender   rank
# 0   True   True    True   True
# 1   True   True    True   True
# 2   True  False    True   True
# 3  False  False   False  False
# 4   True  False    True  False
# 5   True   True    True  False
# 6   True   True    True   True

# %%
mask = pd.isnull(ranking_df['age'])
ranking_df[mask] #only return when age is null(NaN)
# Out:
#     name  age  gender  rank
# 2    tim  NaN    male   4.0
# 3    NaN  NaN     NaN   NaN
# 4  jolin  NaN  female   NaN

# %%
ranking_df.fillna(0)
# Out:
#       name   age  gender  rank
# 0    steve  20.0    male   2.0
# 1     john  22.0    male   1.0
# 2      tim   0.0    male   4.0
# 3        0   0.0       0   0.0
# 4    jolin   0.0  female   0.0
# 5   mathew  21.0    male   0.0
# 6  micheal  23.0    male   6.0

# %%
ranking_df.fillna(method='pad') # missing value alternated by last row value
# Out:
# /tmp/ipykernel_48642/3800408855.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ranking_df.fillna(method='pad') # missing value alternated by last row value
#       name   age  gender  rank
# 0    steve  20.0    male   2.0
# 1     john  22.0    male   1.0
# 2      tim  22.0    male   4.0
# 3      tim  22.0    male   4.0
# 4    jolin  22.0  female   4.0
# 5   mathew  21.0    male   4.0
# 6  micheal  23.0    male   6.0

# %%
ranking_df.fillna(method='bfill') # back fill gon find the next not null value
# Out:
# /tmp/ipykernel_48642/3454728958.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ranking_df.fillna(method='bfill') # back fill gon find the next not null value
#       name   age  gender  rank
# 0    steve  20.0    male   2.0
# 1     john  22.0    male   1.0
# 2      tim  21.0    male   4.0
# 3    jolin  21.0  female   6.0
# 4    jolin  21.0  female   6.0
# 5   mathew  21.0    male   6.0
# 6  micheal  23.0    male   6.0

# %%
ranking_df.interpolate(method='linear')  # Perform interpolation
# Out:
# /tmp/ipykernel_48642/2840072075.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ranking_df.interpolate(method='linear')  # Perform interpolation
#       name    age  gender  rank
# 0    steve  20.00    male   2.0
# 1     john  22.00    male   1.0
# 2      tim  21.75    male   4.0
# 3      NaN  21.50     NaN   4.5
# 4    jolin  21.25  female   5.0
# 5   mathew  21.00    male   5.5
# 6  micheal  23.00    male   6.0

# %%
ranking_df.dropna()
# Out:
#       name   age gender  rank
# 0    steve  20.0   male   2.0
# 1     john  22.0   male   1.0
# 6  micheal  23.0   male   6.0

# %%
ranking_df.dropna(how='all') #row or colume要所有值都是NaN才會被dropped ex row=3
# Out:
#       name   age  gender  rank
# 0    steve  20.0    male   2.0
# 1     john  22.0    male   1.0
# 2      tim   NaN    male   4.0
# 4    jolin   NaN  female   NaN
# 5   mathew  21.0    male   NaN
# 6  micheal  23.0    male   6.0

# %%
ranking_df.dropna(axis=1) #所有colume只要有包含一個NaN 就要被drop
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
ranking_df.dropna(axis=0) #所有row只要有包含一個NaN 就要被drop
# Out:
#       name   age gender  rank
# 0    steve  20.0   male   2.0
# 1     john  22.0   male   1.0
# 6  micheal  23.0   male   6.0
